# %%
def load_django_env():
    import os
    import sys

    import django

    sys.path.append("../")
    os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings.production")

    django.setup()


load_django_env()

# %%
import requests

url = "http://localhost:8000/api/professions/advocates/?search=jeckonia"
headers = {
    "Authorization": "Token c761b92489f7be598ed98d8cf7eb5c89075c28f1",
}

response = requests.get(url, headers=headers, timeout=30)  # verify=False only if self-signed cert
print(response.status_code, response.json())
# Out:
#             DEBUG 2025-08-21 22:44:06,737 connectionpool 5952
#             11168 Starting new HTTP connection (1): localhost:8000
#
#             DEBUG 2025-08-21 22:44:09,129 connectionpool 5952
#             11168 http://localhost:8000 "GET /api/professions/advocates/?search=jeckonia HTTP/1.1" 401 45
# 401 {'detail': 'Invalid token.', 'status_code': 401}
